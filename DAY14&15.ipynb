# %% [markdown]
# # DAY14&15

# %% [markdown]
# ### PANDAS LIBRARY

# %%
import pandas as pd

# %%
ds =pd.read_csv("https://drive.google.com/uc?id=1zO8ekHWx9U7mrbx_0Hoxxu6od7uxJqWw&export=download")
ds
type(ds)
# Out:
# pandas.core.frame.DataFrame

# %%
ds.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
ds.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
print(ds.dtypes)
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
ds.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
ds[['Index','Customer Id','First Name','Last Name','Country','Phone 1', 'Email']]
# Out:
#     Index      Customer Id First Name Last Name                     Country  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter                       Chile
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano                    Djibouti
# 2       3  6F94879bDAfE5a6        Roy     Berry         Antigua and Barbuda
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen          Dominican Republic
# 4       5  053d585Ab6b3159     Joanna    Bender  Slovakia (Slovak Republic)
# ..    ...              ...        ...       ...                         ...
# 95     96  cb8E23e48d22Eae       Karl     Greer                      Guyana
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson                   Sri Lanka
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra             Solomon Islands
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer                       Aruba
# 99    100  2354a0E336A91A1   Clarence    Haynes                    Honduras
#
# ...

# %%
ds[['Index','Customer Id','First Name','Last Name','Country','Phone 1', 'Email']][15:25]
# Out:
#     Index      Customer Id First Name   Last Name  \
# 15     16  8cad0b4CBceaeec    Miranda     Beasley
# 16     17  a5DC21AE3a21eaA   Caroline       Foley
# 17     18  F8Aa9d6DfcBeeF8       Greg        Mata
# 18     19  F160f5Db3EfE973   Clifford    Jacobson
# 19     20  0F60FF3DdCd7aB0     Joanna        Kirk
# 20     21  9F9AdB7B8A6f7F2    Maxwell        Frye
# 21     22  FBd0Ded4F02a742      Kiara     Houston
# 22     23  2FB0FAA1d429421    Colleen      Howard
# 23     24  010468dAA11382c      Janet  Valenzuela
# 24     25  eC1927Ca84E033e      Shane      Wilcox
#
#                                          Country                 Phone 1  \
# 15                                          Oman        540.085.3135x185
# 16                                Western Sahara       936.222.4746x9924
# 17                                    Mozambique           (701)087-2415
# 18  South Georgia and the South Sandwich Islands   001-151-330-3524x0469
# ...

# %%
ds[['Index','Customer Id','First Name','Last Name','Country','Phone 1', 'Email']][15:25:2]
# Out:
#     Index      Customer Id First Name   Last Name  \
# 15     16  8cad0b4CBceaeec    Miranda     Beasley
# 17     18  F8Aa9d6DfcBeeF8       Greg        Mata
# 19     20  0F60FF3DdCd7aB0     Joanna        Kirk
# 21     22  FBd0Ded4F02a742      Kiara     Houston
# 23     24  010468dAA11382c      Janet  Valenzuela
#
#                              Country                 Phone 1  \
# 15                              Oman        540.085.3135x185
# 17                        Mozambique           (701)087-2415
# 19                  French Polynesia       (266)131-7001x711
# 21                       Netherlands  001-274-040-3582x10611
# 23  Lao People's Democratic Republic       354.259.5062x7538
#
#                                Email
# 15           vduncan@parks-hardy.com
# 17           jaredjuarez@carroll.org
# 19           tuckerangie@salazar.net
# 21  blanchardbob@wallace-shannon.com
# 23             stefanie71@spence.com

# %%
ds['new_col']=0
print(ds)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
ds.insert(loc=3, column='Food', value=0)
print(ds)
# Out:
#     Index      Customer Id First Name  Food Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl     0    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston     0    Lozano
# 2       3  6F94879bDAfE5a6        Roy     0     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     0     Olsen
# 4       5  053d585Ab6b3159     Joanna     0    Bender
# ..    ...              ...        ...   ...       ...
# 95     96  cb8E23e48d22Eae       Karl     0     Greer
# 96     97  CeD220bdAaCfaDf       Lynn     0  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred     0    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne     0    Farmer
# 99    100  2354a0E336A91A1   Clarence     0    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# ...

# %%
a=ds[['Index','Customer Id','First Name','Last Name','Country','Phone 1', 'Email']][15:25]
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
x=['a','b','c','d','e','e','f','g','h','i','j']
pd.DataFrame(a, index=x)
# Out:
#    Index Customer Id First Name Last Name Country Phone 1 Email
# a    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# b    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# c    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# d    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# e    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# e    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# f    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# g    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# h    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# i    NaN         NaN        NaN       NaN     NaN     NaN   NaN
# j    NaN         NaN        NaN       NaN     NaN     NaN   NaN

# %%
m1=pd.int([100,200,300,400,500], index=[1,2,3,4,5])
m2=pd.int([600,700,800,900,1000], index=[6,7,8,9,10])

m3=pd.concat([m1,m2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 m1=pd.int([100,200,300,400,500], index=[1,2,3,4,5])
#       2 m2=pd.int([600,700,800,900,1000], index=[6,7,8,9,10])
#       4 m3=pd.concat([m1,m2])
#
# AttributeError: module 'pandas' has no attribute 'int'

# %%
ds.drop("Index", axis=1)
# Out:
#         Customer Id First Name Last Name                          Company  \
# 0   DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 1   1Ef7b82A4CAAD10    Preston    Lozano                      Vega-Gentry
# 2   6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 3   5Cef8BFA16c5e3c      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 4   053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ..              ...        ...       ...                              ...
# 95  cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 96  CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 97  28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 98  c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 99  2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...

# %%
ds.drop(4)
# Out:
#         Customer Id First Name Last Name                          Company  \
# 0   DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 1   1Ef7b82A4CAAD10    Preston    Lozano                      Vega-Gentry
# 2   6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 3   5Cef8BFA16c5e3c      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 5   2d08FB17EE273F4      Aimee     Downs                     Steele Group
# ..              ...        ...       ...                              ...
# 95  cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 96  CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 97  28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 98  c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 99  2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                  City                 Country                 Phone 1  \
# ...

# %%
ds.set_index('Customer Id')
# Out:
#                 First Name Last Name                          Company  \
# Customer Id
# DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 1Ef7b82A4CAAD10    Preston    Lozano                      Vega-Gentry
# 6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 5Cef8BFA16c5e3c      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ...                    ...       ...                              ...
# cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                               City                     Country  \
# Customer Id
# ...

# %%
ds.reset_index()
# Out:
#     index      Customer Id First Name Last Name  \
# 0       0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       1  1Ef7b82A4CAAD10    Preston    Lozano
# 2       2  6F94879bDAfE5a6        Roy     Berry
# 3       3  5Cef8BFA16c5e3c      Linda     Olsen
# 4       4  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     95  cb8E23e48d22Eae       Karl     Greer
# 96     96  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     97  28CDbC0dFe4b1Db       Fred    Guerra
# 98     98  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99     99  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
ds.dropna()
# Out:
#         Customer Id First Name Last Name                          Company  \
# 0   DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 1   1Ef7b82A4CAAD10    Preston    Lozano                      Vega-Gentry
# 2   6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 3   5Cef8BFA16c5e3c      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 4   053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ..              ...        ...       ...                              ...
# 95  cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 96  CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 97  28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 98  c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 99  2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...

# %%
ds.dropna(axis=1)
# Out:
#         Customer Id First Name Last Name                          Company  \
# 0   DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 1   1Ef7b82A4CAAD10    Preston    Lozano                      Vega-Gentry
# 2   6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 3   5Cef8BFA16c5e3c      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 4   053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ..              ...        ...       ...                              ...
# 95  cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 96  CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 97  28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 98  c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 99  2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...

# %%
ds.fillna("xyz")
# Out:
#         Customer Id First Name Last Name                          Company  \
# 0   DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 1   1Ef7b82A4CAAD10    Preston    Lozano                      Vega-Gentry
# 2   6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 3   5Cef8BFA16c5e3c      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 4   053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ..              ...        ...       ...                              ...
# 95  cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 96  CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 97  28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 98  c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 99  2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...
